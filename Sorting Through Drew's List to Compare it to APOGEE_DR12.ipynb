# %%
import numpy as np
from matplotlib import pyplot as plt
import math
import matplotlib.mlab as mlab
% matplotlib inline
from astropy.io import fits
import

# %%
# Calling the postion string column of the list only
infile=np.loadtxt('Copy_of_Drews_List.lis',dtype='string',usecols=[3])

# %%
print infile
# Out:
# ['2M00023036+8524194' '2M00023179+1521164' '2M00024876-0018006' ...,
#  '2M23564129+1445094' '2M23571885+5659355' '2M23594193+1501119']

# %%
# Sort Drew's List string position names from least to greatest
sorted_positions = sorted(infile)

# %%
# List of sorted position strings
print sorted_positions
# Out:
# ['2M00023036+8524194', '2M00023179+1521164', '2M00024876-0018006', '2M00050265+0116236', '2M00062867+6955129', '2M00065234+0151397', '2M00065508+0154022', '2M00090703+8427517', '2M00092179+0038065', '2M00134329+7346435', '2M00150792+6559126', '2M00170781+8551505', '2M00182859+6207248', '2M00254729+7011069', '2M00265252+6359169', '2M00280680+5558136', '2M00302865+5553105', '2M00304380+6752210', '2M00360002+5519491', '2M00370544+6247057', '2M00373811+5912258', '2M00380685+5533175', '2M00411929+1718359', '2M00430905+8407348', '2M00435946+1808423', '2M00443313+1734287', '2M00443463+1719220', '2M00444105+8351358', '2M00462111+1758470', '2M00470197+1751448', '2M00593409+8503084', '2M01004285+8624021', '2M01013134+8424428', '2M01085752+8445142', '2M01193634+8435481', '2M01194897+8532293', '2M01321071+6634585', '2M01325477+6205304', '2M01345988+6651462', '2M01522822+8459249', '2M01525005-0353374', '2M01540092-0306019', '2M01561714+8458408', '2M01562189-0223547', '2M01570057-0216176', '2M0158
# ...

# %%
#DR12= fits.open("./apStar-r5-2M03400448+3118568.fits")
DR12 = open('\\\\ion.physics.wwu.edu\\CoveyData\\APOGEE_Spectra\\APOGEE_DR12_ApStar','r+')
print DR12
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-34-11250cbbdee6> in <module>()
#       1 #DR12= fits.open("./apStar-r5-2M03400448+3118568.fits")
# ----> 2 DR12 = open('\\\\ion.physics.wwu.edu\\CoveyData\\APOGEE_Spectra\\APOGEE_DR12_ApStar','r+')
#       3 print DR12
#
# IOError: [Errno 13] Permission denied: '\\\\ion.physics.wwu.edu\\CoveyData\\APOGEE_Spectra\\APOGEE_DR12_ApStar'

# %%
# Argument for comparing the strings from Drew's List to that of DR12
#import re

#list1 = ["Po2311tato","Pin2231eap","Orange2231edg","add22131dfes"]
#list2 = ["2311","233412","2231"]
#matchlist = []

#for str1 in list1:
   # for str2 in list2:
      #  if (re.search(str2, str1)):
           #matchlist.append(str1)
        #    break

#print matchlist

# %%
try:
    fp = open("\\\\ion.physics.wwu.edu\\CoveyData\\APOGEE_Spectra\\APOGEE_DR12_ApStar")
except IOError as e:
    if e.errno == errno.EACCES:
        return "Some Data"
    # Not a permission error.
    raise
else:
    with fp:
        return fp.read()
# Out:
#   File "<ipython-input-32-0ceebbb29803>", line 5
#     return "Some Data"
# SyntaxError: 'return' outside function
